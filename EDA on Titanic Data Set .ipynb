# %% [markdown]
# ## Import Libraries
# Let's import some libraries to get started!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## The Data
# Let's import some libraries to get started!

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.boxplot()
plt.show()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.drop(["PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
sns.countplot(x="Survived",data=df)
plt.show()

# %%
df["Survived"].value_counts()/len(df)*100
# Out:
# 0    59.550562
# 1    40.449438
# Name: Survived, dtype: float64

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=df,palette='RdBu_r')
plt.show()

# %%
sns.countplot(x="Pclass",data=df)
plt.show()

# %%
df["Pclass"].value_counts()/len(df)*100
# Out:
# 3    49.859551
# 1    25.842697
# 2    24.297753
# Name: Pclass, dtype: float64

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=df,palette='rainbow')
plt.show()

# %%
sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=40)
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\809787043.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=40)

# %%
df['Age'].hist(bins=30,color='darkred',alpha=0.3)
plt.show()

# %%
sns.distplot(df["Age"])
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\3089530644.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])

# %%
sns.countplot(x='SibSp',data=df,palette="bwr")
plt.show()

# %%
df['Fare'].hist(color='green',bins=40,figsize=(8,4))
plt.show()

# %%
sns.boxplot(df["Age"])
plt.show()

# %% [markdown]
# # Survival with respect to Pclass

# %%
sns.countplot(x="Pclass",hue="Survived",data=df,palette="icefire",color="b")
plt.show()

# %% [markdown]
# # Survival with respect to Gender

# %%
sns.countplot(x="Sex",hue="Survived",data=df,palette="Blues",color="g")
plt.show()

# %% [markdown]
# # Survival with respect to Age

# %%
sns.distplot(df[df["Survived"]==0]["Age"],color="r")
sns.distplot(df[df["Survived"]==1]["Age"],color="b")
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\1217098732.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Survived"]==0]["Age"],color="r")
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\1217098732.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Survival with respect to Fare

# %%
pd.crosstab(df["Pclass"],df["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          64  120
# 2          90   83
# 3         270   85

# %%
pd.crosstab(df["Sex"],df["Survived"])
# Out:
# Survived    0    1
# Sex
# female     64  195
# male      360   93

# %%
df.corr()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.356462 -0.082446 -0.015523  0.095265  0.266100
# Pclass   -0.356462  1.000000 -0.365902  0.065187  0.023666 -0.552893
# Age      -0.082446 -0.365902  1.000000 -0.307351 -0.187896  0.093143
# SibSp    -0.015523  0.065187 -0.307351  1.000000  0.383338  0.139860
# Parch     0.095265  0.023666 -0.187896  0.383338  1.000000  0.206624
# Fare      0.266100 -0.552893  0.093143  0.139860  0.206624  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_54028\2271070662.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
